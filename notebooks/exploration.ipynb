# %% [markdown]
# # Gapper-Analyse Exploration
#
# Notebook fuer explorative Datenanalyse der Gapper-Daten.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import duckdb

from config import *

print('Setup OK')
